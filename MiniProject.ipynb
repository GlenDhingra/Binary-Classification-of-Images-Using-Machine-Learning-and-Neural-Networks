# %%
import numpy as np
from PIL import Image
from scipy import ndimage
from dnn_app_utils_v3 import *

# %%
num_px = 64
parameters = np.load("weights.npy",allow_pickle="TRUE").item()

# %%
from PIL import Image

parameters = np.load("weights.npy",allow_pickle="TRUE").item()

fileImage = Image.open("Images/test_2.jpg").convert("RGB").resize([num_px,num_px],Image.ANTIALIAS)
my_label_y = [1] # the true class of your image (1 -> cat, 0 -> non-cat)

image = np.array(fileImage)
my_image = image.reshape(num_px*num_px*3,1)
my_image = my_image/255.
my_predicted_image = predict(my_image, my_label_y, parameters)

plt.imshow(image)
if my_predicted_image[0] == 1:
    print('cat')
else:
    print('dog')
# Out:
# Accuracy: 0.0
# dog
# C:\Users\glend\AppData\Local\Temp\ipykernel_28376\2045109220.py:5: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   fileImage = Image.open("Images/test_2.jpg").convert("RGB").resize([num_px,num_px],Image.ANTIALIAS)

# %%
# Out:
# array([[1.]])
